# %% [markdown]
# # One-Dte Strategy
#
# Author: Laurent Lanteigne
# Date: 2025-07-28

# %% [markdown]
# ## Imports

# %%
import polars as pl
import datetime

from one_dte_trade.data import (
    OneDTEDataPipeline,
)
from one_dte_trade.strategy_signal import (
    SignalGenerator,
)
from one_dte_trade.backtester import (
    Backtester,
)
from one_dte_trade.analysis import (
    Analyzer,
)
# Out:
# Initializing package and loading configurations...
# MockCatLoader initialized. Will use cached Parquet files.
# Configurations loaded successfully from /home/laurent/git_projects/trading_strategies/one_dte_trade/src/one_dte_trade/configs/project_settings.json
# Package initialization complete. Config objects are now available.

# %%
import warnings
warnings.filterwarnings('ignore', category=UserWarning)
warnings.filterwarnings('ignore', category=pl.exceptions.PerformanceWarning)
pl.Config.set_tbl_rows(30)
pl.Config.set_tbl_cols(30)
# Out:
# polars.config.Config

# %% [markdown]
# ### Loading Classes

# %%
pipeline = OneDTEDataPipeline()
signal = SignalGenerator()
backtester = Backtester()
analyzer = Analyzer()
# Out:
# OneDTEDataPipeline: Initializing with pre-loaded configurations...
# StraddleDataPipeline initialized with TICKER_ID: 108105
# VolatilityIndicesFetcher initialized.
# FeatureBuilder initialized with VOL_EWMA: 5, ZSCORE_TIME: 252
# OneDTEDataPipeline: Components initialized.
# SignalGenerator initialized with LAGS: (1, 2, 3), WEIGHTS: (0.6, 0.3, 0.1)
# Backtester initialized with CAPITAL: 1,000,000, WEIGHT_PER_TRADE: 0.05
# Analyzer initialized with plot style from config: whitegrid

# %% [markdown]
# ### Generating Backtest

# %%
# %%capture --no-display
df = pipeline.get_1dte_data(generate_features=True)
df = signal.generate_signals(input_df=df)
df = backtester.generate_backtest_results(df)
# Out:
# 2025-07-28 12:25:10,242 - root - INFO - Calling get_1dte_data(<one_dte_trade.data.OneDTEDataPipeline object at 0x767f50164af0>, generate_features=True)
# 2025-07-28 12:25:10,243 - root - INFO - Calling get_open_straddle_data(<one_dte_trade.straddle_data.StraddleDataPipeline object at 0x767f50164bb0>)
# 2025-07-28 12:25:13,959 - root - INFO - 'get_open_straddle_data' returned DataFrame with shape (1284, 8)
# 2025-07-28 12:25:13,960 - root - INFO - Calling get_close_straddle_data(<one_dte_trade.straddle_data.StraddleDataPipeline object at 0x767f50164bb0>)
# 2025-07-28 12:25:14,787 - root - INFO - 'get_close_straddle_data' returned DataFrame with shape (276260, 7)
# 2025-07-28 12:25:14,788 - root - INFO - Calling merge_open_trade_close_trade(<one_dte_trade.straddle_data.StraddleDataPipeline object at 0x767f50164bb0>, arg1(DataFrame shape=(1284, 8)), arg2(DataFrame shape=(276260, 7)))
# 2025-07-28 12:25:14,801 - root - INFO - 'merge_open_trade_close_trade' returned DataFrame with shape (1278, 9)
# 2025-07-28 12:25:14,801 - root - INFO - Calling pivot_data(<one_dte_trade.straddle_data.StraddleDataPipeline object at 0x767f50164bb0>, arg1(DataFrame shape=(1278, 9)))
# 2025-07-28 12:25:14,804 - root - INFO - 'pivot_data' returned DataFrame with shape (639, 10)
# 2025-07-28 12:25:14,804 - root - INFO - Calling calculate_straddle_prices(<one_dte_trade.straddle_data.StraddleDataPipeline object at 0x767f50164bb0>, arg1(DataFrame shape=(639, 10)))
# 2025-07-28 12:25:14,805 - root - INFO - 'calculate_straddle_prices' returned DataFrame with shape (639, 13)
# 2025-07-28 12:25:14,806 - root - INFO - Calling get_all_volatility_prices(<one_dte_trade.vol_indicies.VolatilityIndicesFetcher object at 0x767f501644c0>)
# 2025-07-28 12:25:14,806 - root - INFO - Calling _fetch_price_for_security(<one_dte_trade.vol_indicies.VolatilityIndicesFetcher object at 0x767f501644c0>, 117801, 'VIX')
# 2025-07-28 12:25:14,808 - root - INFO - '_fetch_price_for_security' returned DataFrame with shape (2407, 2)
# 2025-07-28 12:25:14,808 - root - INFO - Calling _fetch_price_for_security(<one_dte_trade.vol_indicies.VolatilityIndicesFetcher object at 0x767f501644c0>, 152892, 'VVIX')
# 2025-07-28 12:25:14,810 - root - INFO - '_fetch_price_for_security' returned DataFrame with shape (2405, 2)
# 2025-07-28 12:25:14,810 - root - INFO - Calling _fetch_price_for_security(<one_dte_trade.vol_indicies.VolatilityIndicesFetcher object at 0x767f501644c0>, 145764, 'VIXM')
# 2025-07-28 12:25:14,811 - root - INFO - '_fetch_price_for_security' returned DataFrame with shape (2409, 2)
# 2025-07-28 12:25:14,814 - root - INFO - Calling calculate_vol_ts(<one_dte_trade.vol_indicies.VolatilityIndicesFetcher object at 0x767f501644c0>, arg1(DataFrame shape=(2405, 4)))
# 2025-07-28 12:25:14,815 - root - INFO - 'calculate_vol_ts' returned DataFrame with shape (2405, 5)
# 2025-07-28 12:25:14,816 - root - INFO - 'get_all_volatility_prices' returned DataFrame with shape (2405, 5)
# 2025-07-28 12:25:14,817 - root - INFO - Calling calculate_vol_zscore(<one_dte_trade.features.FeatureBuilder object at 0x767f50164490>, arg1(DataFrame shape=(2405, 5)))
# 2025-07-28 12:25:14,817 - root - INFO - Calling _calculate_vol_ewma(<one_dte_trade.features.FeatureBuilder object at 0x767f50164490>, df=DataFrame(shape=(2405, 5)))
# 2025-07-28 12:25:14,819 - root - INFO - '_calculate_vol_ewma' returned DataFrame with shape (2405, 8)
# 2025-07-28 12:25:14,820 - root - INFO - 'calculate_vol_zscore' returned DataFrame with shape (2405, 8)
# 2025-07-28 12:25:14,821 - root - INFO - Calling calculate_spx_ret(<one_dte_trade.features.FeatureBuilder object at 0x767f50164490>, arg1(StraddleDataConfig))
# 2025-07-28 12:25:14,821 - root - INFO - Calling _get_spx_data(<one_dte_trade.features.FeatureBuilder object at 0x767f50164490>, straddle_config=StraddleDataConfig)
# 2025-07-28 12:25:14,822 - root - INFO - '_get_spx_data' returned <LazyFrame at 0x767F50165360>
# 2025-07-28 12:25:14,822 - root - INFO - Calling _compute_spx_ret(<one_dte_trade.features.FeatureBuilder object at 0x767f50164490>, lf=<LazyFrame at 0x767F50165360>)
# 2025-07-28 12:25:14,825 - root - INFO - '_compute_spx_ret' returned DataFrame with shape (2404, 2)
# 2025-07-28 12:25:14,825 - root - INFO - 'calculate_spx_ret' returned DataFrame with shape (2404, 2)
# 2025-07-28 12:25:14,827 - root - INFO - 'get_1dte_data' returned DataFrame with shape (639, 21)
# 2025-07-28 12:25:14,832 - root - INFO - Calling generate_signals(<one_dte_trade.strategy_signal.SignalGenerator object at 0x767f501649d0>, input_df=DataFrame(shape=(639, 21)))
# 2025-07-28 12:25:14,833 - root - INFO - Calling _calculate_straddle_returns(<one_dte_trade.strategy_signal.SignalGenerator object at 0x767f501649d0>, arg1(DataFrame shape=(639, 21)))
# 2025-07-28 12:25:14,834 - root - INFO - '_calculate_straddle_returns' returned DataFrame with shape (639, 23)
# 2025-07-28 12:25:14,835 - root - INFO - Calling _calculate_signal_components(<one_dte_trade.strategy_signal.SignalGenerator object at 0x767f501649d0>, arg1(DataFrame shape=(639, 23)))
# 2025-07-28 12:25:14,836 - root - INFO - '_calculate_signal_components' returned DataFrame with shape (639, 37)
# 2025-07-28 12:25:14,838 - root - INFO - 'generate_signals' returned DataFrame with shape (636, 37)
# 2025-07-28 12:25:14,839 - root - INFO - Calling generate_backtest_results(<one_dte_trade.backtester.Backtester object at 0x767f50164a60>, arg1(DataFrame shape=(636, 37)))
# 2025-07-28 12:25:14,839 - root - INFO - Calling _calculate_capital_per_trade(<one_dte_trade.backtester.Backtester object at 0x767f50164a60>, arg1(DataFrame shape=(636, 37)))
# 2025-07-28 12:25:14,840 - root - INFO - '_calculate_capital_per_trade' returned DataFrame with shape (636, 39)
# 2025-07-28 12:25:14,841 - root - INFO - Calling _calculate_number_positions(<one_dte_trade.backtester.Backtester object at 0x767f50164a60>, arg1(DataFrame shape=(636, 39)))
# 2025-07-28 12:25:14,842 - root - INFO - '_calculate_number_positions' returned DataFrame with shape (636, 41)
# 2025-07-28 12:25:14,843 - root - INFO - Calling _calculate_daily_pnl(<one_dte_trade.backtester.Backtester object at 0x767f50164a60>, arg1(DataFrame shape=(636, 41)))
# 2025-07-28 12:25:14,844 - root - INFO - '_calculate_daily_pnl' returned DataFrame with shape (636, 43)
# 2025-07-28 12:25:14,845 - root - INFO - Calling _calculate_cumulative_pnl(<one_dte_trade.backtester.Backtester object at 0x767f50164a60>, arg1(DataFrame shape=(636, 43)))
# 2025-07-28 12:25:14,845 - root - INFO - '_calculate_cumulative_pnl' returned DataFrame with shape (636, 45)
# 2025-07-28 12:25:14,846 - root - INFO - 'generate_backtest_results' returned DataFrame with shape (636, 45)

# %%
df.head()
# Out:
# shape: (5, 45)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬───┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ dat ┆ oke ┆ upr ┆ exp ┆ dis ┆ upr ┆ spr ┆ spr ┆ spr ┆ spr ┆ str ┆ str ┆ upr ┆ VIX ┆ VVI ┆ … ┆ ret ┆ ret ┆ ret ┆ ret ┆ ret ┆ ret ┆ ret ┆ ret ┆ ret ┆ ret ┆ ret ┆ ret ┆ ret ┆ ret ┆ ret │
# │ e   ┆ y_x ┆ c_d ┆ ira ┆ t_t ┆ c_d ┆ c_d ┆ c_d ┆ c_d ┆ c_d ┆ add ┆ add ┆ c_d ┆ --- ┆ X   ┆   ┆ _sp ┆ _sp ┆ _up ┆ _up ┆ _up ┆ _sp ┆ _up ┆ _sp ┆ _up ┆ _sp ┆ _up ┆ _sp ┆ _up ┆ _sp ┆ _up │
# │ --- ┆ x   ┆ ay_ ┆ tio ┆ o_s ┆ ay_ ┆ ay_ ┆ ay_ ┆ ay_ ┆ ay_ ┆ le_ ┆ le_ ┆ iff ┆ f32 ┆ --- ┆   ┆ rc_ ┆ rc_ ┆ rc_ ┆ rc_ ┆ rc_ ┆ rc_ ┆ rc_ ┆ rc_ ┆ rc_ ┆ rc_ ┆ rc_ ┆ rc_ ┆ rc_ ┆ rc_

# └─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴───┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┘

# %% [markdown]
# # Strategy Perfomance
# ## Cumulative PnL from 2023 - Present

# %%
analyzer.plot_timeseries(df, time_col='date', value_col='ret_uprc_signal_cum_pnl', title='1DTE Strategy Cumulative PnL Total', ylabel='PnL')

# %% [markdown]
# ## Cumulative PnL by Years

# %%
dates = [datetime.date(2023,1,1), datetime.date(2024,1,1), datetime.date(2025,1,1), datetime.date(2026,1,1)]
for i in range(1, len(dates)):
    start_date = dates[i-1]
    end_date = min(dates[i], df.get_column('date').last())
    tmp = df.filter(
        pl.col("date").is_between(start_date, end_date, closed="left")
    )
    tmp = tmp.with_columns(pl.col('ret_uprc_signal_cum_pnl') - pl.col('ret_uprc_signal_cum_pnl').first())
    title = f'1DTE Strategy Cumulative PnL Total {start_date.strftime("%Y-%m-%d")} : {end_date.strftime("%Y-%m-%d")}'
    analyzer.plot_timeseries(tmp, time_col='date', value_col='ret_uprc_signal_cum_pnl', title=title, ylabel='PnL')

# %% [markdown]
# ## PnL Statistics Long and Short

# %%
analyzer.calculate_pnl_statistics(df=df, pnl_col_name='ret_uprc_signal_pnl')
# Out:
# shape: (15, 2)
# ┌──────────────────────────────┬────────────────┐
# │ Statistic                    ┆ Value          │
# │ ---                          ┆ ---            │
# │ str                          ┆ f64            │
# ╞══════════════════════════════╪════════════════╡
# │ Mean Daily PnL               ┆ 2725.735801    │
# │ Std Dev Daily PnL            ┆ 18094.067705   │
# │ Annualized Sharpe Ratio      ┆ 2.391376       │
# │ Win Rate (%)                 ┆ 52.044025      │
# │ Max Daily Win                ┆ 113748.01533   │
# │ Max Daily Loss               ┆ -153567.370679 │
# │ Worst 5-Day Cum PnL (%)      ┆ -9.34043       │
# │ Worst 20-Day Cum PnL (%)     ┆ -11.948517     │
# │ Skewness                     ┆ 0.194894       │
# │ Kurtosis                     ┆ 12.987437      │
# │ Average Win Amount           ┆ 14086.202073   │
# │ Average Loss Amount          ┆ -9603.163662   │
# │ Total Return (%) over Period ┆ 173.356797     │
# │ Annualized Total Return (%)  ┆ 48.951168      │
# │ Count                        ┆ 636.0          │
# └──────────────────────────────┴────────────────┘

# %% [markdown]
# ## PnL Statistics Short

# %%
tmp = df.filter(pl.col('ret_uprc_signal_pos') < 0)
analyzer.calculate_pnl_statistics(df=tmp, pnl_col_name='ret_uprc_signal_pnl')
# Out:
# shape: (15, 2)
# ┌──────────────────────────────┬────────────────┐
# │ Statistic                    ┆ Value          │
# │ ---                          ┆ ---            │
# │ str                          ┆ f64            │
# ╞══════════════════════════════╪════════════════╡
# │ Mean Daily PnL               ┆ 4640.804304    │
# │ Std Dev Daily PnL            ┆ 20277.481723   │
# │ Annualized Sharpe Ratio      ┆ 3.633118       │
# │ Win Rate (%)                 ┆ 63.309353      │
# │ Max Daily Win                ┆ 113748.01533   │
# │ Max Daily Loss               ┆ -153567.370679 │
# │ Worst 5-Day Cum PnL (%)      ┆ -10.438946     │
# │ Worst 20-Day Cum PnL (%)     ┆ -6.224827      │
# │ Skewness                     ┆ -0.598873      │
# │ Kurtosis                     ┆ 17.339436      │
# │ Average Win Amount           ┆ 13668.53883    │
# │ Average Loss Amount          ┆ -10936.463113  │
# │ Total Return (%) over Period ┆ 129.01436      │
# │ Annualized Total Return (%)  ┆ 111.936857     │
# │ Count                        ┆ 278.0          │
# └──────────────────────────────┴────────────────┘

# %% [markdown]
# ## PnL Statistics Long

# %%
tmp = df.filter(pl.col('ret_uprc_signal_pos') > 0)
analyzer.calculate_pnl_statistics(df=tmp, pnl_col_name='ret_uprc_signal_pnl')
# Out:
# shape: (15, 2)
# ┌──────────────────────────────┬───────────────┐
# │ Statistic                    ┆ Value         │
# │ ---                          ┆ ---           │
# │ str                          ┆ f64           │
# ╞══════════════════════════════╪═══════════════╡
# │ Mean Daily PnL               ┆ 1238.615567   │
# │ Std Dev Daily PnL            ┆ 16069.604662  │
# │ Annualized Sharpe Ratio      ┆ 1.223578      │
# │ Win Rate (%)                 ┆ 43.296089     │
# │ Max Daily Win                ┆ 90641.23894   │
# │ Max Daily Loss               ┆ -34288.004391 │
# │ Worst 5-Day Cum PnL (%)      ┆ -8.646096     │
# │ Worst 20-Day Cum PnL (%)     ┆ -13.235266    │
# │ Skewness                     ┆ 1.2636        │
# │ Kurtosis                     ┆ 3.542904      │
# │ Average Win Amount           ┆ 14560.451949  │
# │ Average Loss Amount          ┆ -8933.229947  │
# │ Total Return (%) over Period ┆ 44.342437     │
# │ Annualized Total Return (%)  ┆ 29.478945     │
# │ Count                        ┆ 358.0         │
# └──────────────────────────────┴───────────────┘

# %% [markdown]
# # Signal Analysis
# ## Autocorrelation of Straddle Returns

# %%
analyzer.plot_signal_autocorrelation(df=df, signal_cols_to_analyze=['ret_sprc', 'ret_uprc_signal', 'ret_uprc_signal_pnl'])

# %% [markdown]
# ## Daily Signal PnL Distribution

# %%
analyzer.plot_histogram_kde(df=df, value_col="ret_uprc_signal_pnl", title="Daily Signal PnL", xlabel="Daily PnL")

# %% [markdown]
# ## Daily Signal Distribution

# %%
analyzer.plot_histogram_kde(df=df, value_col="ret_uprc_signal", title="Daily Signal Direction", xlabel="Signal Weight")

# %% [markdown]
# ## Daily Signal PnL Timeseries

# %%
analyzer.plot_pnl_bars(df=df, date_col='date', pnl_col='ret_uprc_signal_pnl')

# %% [markdown]
# ## Weekly Signal PnL Timeseries

# %%
analyzer.plot_pnl_bars(df=df, date_col='date', pnl_col='ret_uprc_signal_pnl', aggregation_period="weekly")

# %% [markdown]
# # Regime Analysis
# ## Strategy Sharpe Ratio by Decile of Signal

# %%
analyzer.plot_signal_decile_sharpe_barchart(df=df, signal_bases=['ret_uprc_signal'])

# %% [markdown]
# ## Strategy Sharpe by Volatility Environment

# %%
analyzer.plot_column_decile_signal_sharpe_barchart(df=df, columns_to_decile=["VIX", "VVIX", "VIX_TS"], signal_bases=["ret_uprc_signal"])

# %% [markdown]
# ## Strategy Sharpe by Moving Average of Volatility Environment

# %%
analyzer.plot_column_fixed_bin_signal_sharpe_barchart(df=df, columns_to_bin=["VIX_ewma_hl_5_zscore", "VVIX_ewma_hl_5_zscore", "VIX_TS_ewma_hl_5_zscore"], signal_bases=["ret_uprc_signal"])
